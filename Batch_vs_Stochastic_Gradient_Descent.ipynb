# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadsajad/100_Days_of_Deep_Learning/blob/main/Batch_vs_Stochastic_Gradient_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import time

# %% [markdown]
# # Downloading the data set from kagle
# https://www.kaggle.com/datasets/rakeshrau/social-network-ads

# %%
# Making directory for uploading kaggle api
# !mkdir -p /root/.kaggle

# %%
# Upload manualy your kaggle api to directory and copy it to the root/.kaggle directory
# !cp kaggle.json /root/.kaggle
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory

# %%
# Now download the dataset from kagle through your api by copying the api cammand of data set present on the data set page
# !kaggle datasets download -d rakeshrau/social-network-ads
# Out:
# Dataset URL: https://www.kaggle.com/datasets/rakeshrau/social-network-ads
# License(s): unknown
# ...
#   0% 0.00/3.27k [00:00<?, ?B/s]
# 100% 3.27k/3.27k [00:00<00:00, 5.41MB/s]

# %%
# Unzip the data set
# !unzip /content/social-network-ads.zip
# Out:
# Archive:  /content/social-network-ads.zip
#   inflating: Social_Network_Ads.csv

# %%
# load the data set into a data frame
df=pd.read_csv('/content/Social_Network_Ads.csv')

# %%
# Display the first five results
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
# We need only two columns from this data frame
df=df[['Age','EstimatedSalary','Purchased']]

# %%
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
# Split the data into X means features and y means labels
X=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
X.head()
# Out:
#    Age  EstimatedSalary
# 0   19            19000
# 1   35            20000
# 2   26            43000
# 3   27            57000
# 4   19            76000

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Purchased, dtype: int64

# %%
# Apply standard scler just to put inputs on same scale as the model converge fast
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

X_scaled=scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_scaled,y,test_size=0.2,random_state=2)

# %%
X_train.shape
# Out:
# (320, 2)

# %%
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %%
model=Sequential()

model.add(Dense(10,activation='relu',input_dim=2))
model.add(Dense(10,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 10)                30
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 1)                 11
#
# ...
# Total params: 151 (604.00 Byte)
# Trainable params: 151 (604.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Batch gradient Descent, as we are using the batch size 320 so its automaticaly batch gradient descent
model.compile(loss='binary_crossentropy',metrics=['accuracy'])
start=time.time()
history=model.fit(X_train,y_train,epochs=10,batch_size=320)
print(time.time() - start)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 1s 811ms/step - loss: 0.6902 - accuracy: 0.4906
# Epoch 2/10
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6787 - accuracy: 0.5719
# Epoch 3/10
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6710 - accuracy: 0.5938
# Epoch 4/10
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6647 - accuracy: 0.6094
# Epoch 5/10
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6592 - accuracy: 0.6562
# Epoch 6/10
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6544 - accuracy: 0.6844
# Epoch 7/10
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6499 - accuracy: 0.6938
# Epoch 8/10
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6458 - accuracy: 0.7156
# Epoch 9/10
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6419 - accuracy: 0.7156
# Epoch 10/10
# ...

# %%
# Stochastic Gradient Descent, as we are using batch_size=1 so its updating weight after each row
model.compile(loss='binary_crossentropy',metrics=['accuracy'])
start=time.time()
history=model.fit(X_train,y_train,epochs=10,batch_size=1)
print(time.time()- start)
# Out:
# Epoch 1/10
# 320/320 [==============================] - 4s 6ms/step - loss: 0.5276 - accuracy: 0.7531
# Epoch 2/10
# 320/320 [==============================] - 1s 3ms/step - loss: 0.3945 - accuracy: 0.8406
# Epoch 3/10
# 320/320 [==============================] - 1s 3ms/step - loss: 0.3345 - accuracy: 0.8719
# Epoch 4/10
# 320/320 [==============================] - 1s 3ms/step - loss: 0.3052 - accuracy: 0.8719
# Epoch 5/10
# 320/320 [==============================] - 1s 3ms/step - loss: 0.2893 - accuracy: 0.8813
# Epoch 6/10
# 320/320 [==============================] - 2s 5ms/step - loss: 0.2779 - accuracy: 0.8844
# Epoch 7/10
# 320/320 [==============================] - 1s 4ms/step - loss: 0.2679 - accuracy: 0.8906
# Epoch 8/10
# 320/320 [==============================] - 1s 3ms/step - loss: 0.2670 - accuracy: 0.8938
# Epoch 9/10
# 320/320 [==============================] - 1s 3ms/step - loss: 0.2653 - accuracy: 0.9000
# Epoch 10/10
# ...
